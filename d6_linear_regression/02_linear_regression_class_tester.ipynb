# %% [markdown]
# # Let's test your implementation of LinearRegression

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
# Import your class here:
#from your_file import LinearRegression
class LinearRegression:
    def __init__(self, *, fit_intercept=True):
        self.fit_intercept = fit_intercept
        
    def fit(self,X,y):
        X_mean = np.mean(X)
        Y_mean = np.mean(y)
        num = 0
        den = 0
        for i in range(len(X)):
            num += (X[i] - X_mean)*(y[i] - Y_mean)
            den += (X[i] - X_mean)**2
        m = num / den
        c = Y_mean - m*X_mean
        
        Y_pred = m*X + c

        plt.scatter(X, Y) # actual
        plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red') # predicted
        plt.show()

# %%
#assert LinearRegression is not None, 'You should import your class'
#assert 'fit' in dir(LinearRegression) and 'predict' in dir(LinearRegression), 'You should follow sklearn conventions'

# %%
# Load the data in X and y
data = pd.read_csv('reg_data.csv')
X=np.array(data.iloc[:,0])
y=np.array(data.iloc[:,1])
X
# Out:
# array([53.42680403, 61.53035803, 47.47563963, 59.81320787, 55.14218841,
#        52.21179669, 39.29956669, 48.10504169, 52.55001444, 45.41973014,
#        54.35163488, 44.1640495 , 58.16847072, 56.72720806, 48.95588857,
#        44.68719623, 60.29732685, 45.61864377, 38.81681754, 66.18981661,
#        65.41605175, 47.48120861, 41.57564262, 51.84518691, 59.37082201,
#        57.31000344, 63.61556125, 46.73761941, 50.55676015, 52.22399609,
#        35.56783005, 42.43647694, 58.16454011, 57.50444762, 45.44053073,
#        61.89622268, 33.09383174, 36.43600951, 37.67565486, 44.55560838,
#        43.31828263, 50.07314563, 43.87061265, 62.99748075, 32.66904376,
#        40.16689901, 53.57507753, 33.86421497, 64.70713867, 38.11982403,
#        44.50253806, 40.59953838, 41.72067636, 51.08863468, 55.0780959 ,
#        41.37772653, 62.49469743, 49.20388754, 41.10268519, 41.18201611,
#        50.18638949, 52.37844622, 50.13548549, 33.64470601, 39.55790122,
#        56.13038882, 57.36205213, 60.26921439, 35.67809389, 31.588117  ,
#        53.66093226, 46.68222865, 43.10782022, 70.34607562, 44.49285588,
#        57.5045333 , 36.93007661, 55.80573336, 38.95476907, 56.9012147 ,
#        56.86890066, 34.3331247 , 59.04974121, 57.78822399, 54.28232871,
#        51.0887199 , 50.28283635, 44.21174175, 38.00548801, 32.94047994,
#        53.69163957, 68.76573427, 46.2309665 , 68.31936082, 50.03017434,
#        49.23976534, 50.03957594, 48.14985889, 25.12848465])

# %%
# Code to plot X vs y
sc_data= plt.scatter(X,y)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# # Fit the model

# %%
p = LinearRegression().fit(X,y)

p

# %%
assert model is not None and type(model) == LinearRegression, 'Fit method should return itself'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-a56a41c8b4b1> in <module>
# ----> 1 assert model is not None and type(model) == LinearRegression, 'Fit method should return itself'
#
# NameError: name 'model' is not defined

# %%
assert X is not None and type(X) == np.ndarray, 'X should be defined and be a numpy array'
assert y is not None and type(y) == np.ndarray, 'y should be defined and be a numpy array'

# %% [markdown]
# # Plot x against y using matplotlib
#
# example:
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Scatter_diagram_for_quality_characteristic_XXX.svg/1200px-Scatter_diagram_for_quality_characteristic_XXX.svg.png" alt="drawing" width="300"/>

# %% [markdown]
# # Plot the line generated by your model
# example:
# <img src="https://howtothink.readthedocs.io/en/latest/_images/mpl_basic.png" alt="drawing" width="300"/>

# %%
# Code to plot X vs H(X)

# %% [markdown]
# # Plot the line generated by your model together with the scatter
# example:
# <img src="https://i.stack.imgur.com/DjuGW.png" alt="drawing" width="300"/>

# %%
# Code to plot X vs H(X) and X vs y
